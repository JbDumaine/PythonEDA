# %% [markdown]
# Exo 2 :

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataSalesPredictions=pd.read_csv('sales_predictions.csv')
dataSalesPredictions.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
sns.relplot(x=dataSalesPredictions["date"],y=dataSalesPredictions["item_price"],data=dataSalesPredictions)

# %%
newDSP = dataSalesPredictions.sample(50)

# %%
sns.relplot(x=newDSP["date"],y=newDSP["item_price"],data=newDSP)
